# %%
import argparse
import csv
import json
import logging
import random, re, shutil, tempfile, psutil, subprocess
import gzip, os, time, glob, platform
from dataclasses import asdict, dataclass, field
from datetime import datetime, timedelta
from io import BytesIO
from pathlib import Path
from typing import Optional
from urllib.parse import urlparse
from urllib.parse import urlparse, parse_qs, urlencode, urlunparse
import pandas as pd
from difflib import SequenceMatcher
 
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException, TimeoutException
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
import xml.etree.ElementTree as ET
import undetected_chromedriver as uc

# ── logging ────────────────────────────────────────────────────────────────────
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    datefmt="%H:%M:%S",
    handlers=[
        logging.StreamHandler(),
        logging.FileHandler("tiket_scraper.log", encoding="utf-8"),
    ],
)
log = logging.getLogger(__name__)

# ── constants ──────────────────────────────────────────────────────────────────
# SITEMAP_INDEX_URL = "https://www.tiket.com/sitemap/id-id/index.xml.gz"
BASE_URL          = "https://www.booking.com"
LOCALE            = "id"
PAGE_TIMEOUT      = 20
MAX_PROPERTIES    = 25
DRIVER_RECYCLE_EVERY = 5
# Linux → VPS mode (Xvfb); anything else (e.g. local Windows) → headed local mode
IS_VPS = platform.system() == "Linux"
 
# Child sitemap name patterns that contain property detail pages (PDP)
PDP_PATTERNS = {
    "hotel":     ["hotel-pdp"],
    "villa":     ["homes-villa"],
    "homes":     ["homes-pdp"],
    "glamping":  ["homes-glamping"],
    "cottage":   ["homes-cottage"],
    "apartment": ["homes-apartment"],
}

def ensure_virtual_display():
    """
    Start Xvfb virtual display if not already running.
    Sets DISPLAY env var so Chrome picks it up automatically.
    """
    display = ":99"

    # Check if Xvfb is already running on this display
    result = subprocess.run(
        ["pgrep", "-f", f"Xvfb {display}"],
        capture_output=True, text=True
    )

    if result.returncode != 0:
        # Not running — start it
        log.info(f"Starting Xvfb on display {display}...")
        subprocess.Popen(
            ["Xvfb", display, "-screen", "0", "1920x1080x24"],
            stdout=subprocess.DEVNULL,
            stderr=subprocess.DEVNULL
        )
         # ── Wait until Xvfb socket actually exists, not just a fixed sleep ──
        socket_path = f"/tmp/.X11-unix/X{display.lstrip(':')}"
        for _ in range(20):          # up to 10s
            if os.path.exists(socket_path):
                log.info(f"Xvfb socket ready: {socket_path}")
                break
            time.sleep(0.5)
        else:
            raise RuntimeError("Xvfb did not start in time — socket never appeared")
    else:
        log.info(f"Xvfb already running on {display}")

    # CRITICAL: set DISPLAY so Chrome finds the virtual screen
    os.environ["DISPLAY"] = display
    log.info(f"DISPLAY set to {display}")

def clear_uc_cache():
    """Delete undetected_chromedriver's cached patched driver.

    UC caches the patched chromedriver (e.g. under %APPDATA%\\undetected_chromedriver
    on Windows). If a wrong-version driver got cached (the v150 vs Chrome-149 error),
    it keeps reusing it. Removing it forces UC to re-download a matching driver.
    """
    try:
        patcher = uc.Patcher()
        exe = getattr(patcher, "executable_path", None)
        if exe and os.path.exists(exe):
            try:
                os.remove(exe)
                log.info(f"Cleared UC cached driver: {exe}")
            except PermissionError:
                log.warning(f"Could not remove {exe} (locked); attempting dir wipe")
        data_dir = getattr(patcher, "data_path", None)
        if data_dir and os.path.isdir(data_dir):
            shutil.rmtree(data_dir, ignore_errors=True)
            log.info(f"Cleared UC data dir: {data_dir}")
    except Exception as e:
        log.warning(f"Could not clear UC cache: {e}")

def get_chrome_version() -> int:
    """Auto-detect installed Chrome major version — no more hardcoding version_main."""
    # ── Windows: registry first, then chrome.exe file metadata ────────────────
    if platform.system() == "Windows":
        try:
            import winreg
            with winreg.OpenKey(winreg.HKEY_CURRENT_USER, r"Software\Google\Chrome\BLBeacon") as key:
                version_str, _ = winreg.QueryValueEx(key, "version")  # e.g. "149.0.7827.201"
                major = int(version_str.split(".")[0])
                log.info(f"Auto-detected Chrome (registry): {version_str} → major version {major}")
                return major
        except Exception as e:
            log.warning(f"Registry Chrome detection failed: {e}")

        # Fallback: read version straight from chrome.exe file metadata
        chrome_paths = [
            os.path.expandvars(r"%ProgramFiles%\Google\Chrome\Application\chrome.exe"),
            os.path.expandvars(r"%ProgramFiles(x86)%\Google\Chrome\Application\chrome.exe"),
            os.path.expandvars(r"%LocalAppData%\Google\Chrome\Application\chrome.exe"),
        ]
        for path in chrome_paths:
            if os.path.exists(path):
                try:
                    result = subprocess.run(
                        ["powershell", "-NoProfile", "-Command",
                         f"(Get-Item '{path}').VersionInfo.ProductVersion"],
                        capture_output=True, text=True, timeout=10
                    )
                    if result.returncode == 0 and result.stdout.strip():
                        version_str = result.stdout.strip()
                        major = int(version_str.split(".")[0])
                        log.info(f"Auto-detected Chrome (exe): {version_str} → major version {major}")
                        return major
                except Exception as e:
                    log.warning(f"Exe Chrome detection failed for {path}: {e}")
        return None

    # ── Linux / VPS: try common Chrome binary names ───────────────────────────
    try:
        for binary in ["google-chrome", "google-chrome-stable", "chromium-browser", "chromium"]:
            result = subprocess.run(
                [binary, "--version"],
                capture_output=True, text=True, timeout=5
            )
            if result.returncode == 0:
                version_str = result.stdout.strip()  # e.g. "Google Chrome 136.0.7103.93"
                major = int(version_str.split()[-1].split(".")[0])
                log.info(f"Auto-detected Chrome: {version_str} → major version {major}")
                return major
    except Exception as e:
        log.warning(f"Could not auto-detect Chrome version: {e}")
    return None   # let UC figure it out itself


def build_driver(download_folder: str, headless: bool):
    # ── On VPS: spin up virtual display so Chrome runs headed ────────────────
    if IS_VPS:
        ensure_virtual_display()

    opts = uc.ChromeOptions()

    prefs = {
        "download.default_directory":         download_folder,
        "download.prompt_for_download":       False,
        "download.directory_upgrade":         True,
        "safebrowsing.enabled":               True,
        "plugins.always_open_pdf_externally": True,
        "intl.accept_languages":              "en-US,en",
    }
    opts.add_experimental_option("prefs", prefs)

    # ── Stability flags (still needed even in headed mode on VPS) ────────────
    opts.add_argument("--no-sandbox")
    opts.add_argument("--disable-dev-shm-usage")
    opts.add_argument("--disable-gpu")              # VPS still has no real GPU
    opts.add_argument("--disable-software-rasterizer")
    opts.add_argument("--disable-extensions")
    opts.add_argument("--disable-background-networking")
    opts.add_argument("--no-first-run")
    opts.add_argument("--no-default-browser-check")
    opts.add_argument("--mute-audio")
    opts.add_argument("--window-size=1920,1080")
    opts.add_argument("--start-maximized")
    opts.add_argument("--lang=en-US,en")

    # ── NO --headless flag at all when using Xvfb ────────────────────────────
    # headless=False both here and in uc.Chrome() call

    # ── Temp profile in shared memory ────────────────────────────────────────
    # shm_available = os.path.exists("/dev/shm") and os.access("/dev/shm", os.W_OK)
    # tmp_base = "/dev/shm" if shm_available else "/tmp"
    # tmp_profile = tempfile.mkdtemp(prefix="chrome_profile_", dir=tmp_base)
    # opts.add_argument(f"--user-data-dir={tmp_profile}")
    # log.info(f"Chrome profile dir: {tmp_profile}")

    chrome_version = get_chrome_version()

    def _start_uc():
        driver_kwargs = {
            "options":  opts,
            "headless": False,   # True headed mode — Xvfb provides the display
        }
        if chrome_version:
            driver_kwargs["version_main"] = chrome_version
        return uc.Chrome(**driver_kwargs)

    try:
        try:
            driver = _start_uc()
            log.info("UC Chrome started in headed mode via Xvfb")
        except Exception as first_err:
            # Most common cause: a stale wrong-version chromedriver cached by UC
            # (the "ChromeDriver only supports Chrome version 150" error). Wipe the
            # cache and retry ONCE with the detected version before giving up on UC.
            log.warning(f"UC Chrome first attempt failed: {first_err}")
            log.info("Clearing UC cache and retrying UC once...")
            clear_uc_cache()
            time.sleep(2)
            driver = _start_uc()
            log.info("UC Chrome started on retry (after cache clear)")

    except Exception as e:
        log.error(f"UC Chrome failed: {e}")
        log.info("Falling back to standard Selenium...")
        # shutil.rmtree(tmp_profile, ignore_errors=True)

        from selenium.webdriver.chrome.service import Service
        from webdriver_manager.chrome import ChromeDriverManager

        std_opts = Options()
        std_opts.add_argument("--no-sandbox")
        std_opts.add_argument("--disable-dev-shm-usage")
        std_opts.add_argument("--disable-gpu")
        std_opts.add_argument("--window-size=1920,1080")
        if IS_VPS and not headless:
            pass   # Xvfb is already running, no --headless needed
        elif headless:
            std_opts.add_argument("--headless=new")
        std_opts.add_experimental_option("prefs", prefs)
        std_opts.add_argument(
            "user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
            "AppleWebKit/537.36 (KHTML, like Gecko) "
            "Chrome/149.0.0.0 Safari/537.36"
        )

        driver = webdriver.Chrome(
            service=Service(ChromeDriverManager().install()),
            options=std_opts
        )
        log.info("Standard Selenium started")

    # driver._tmp_profile = tmp_profile
    return driver

# %%
PROJECT_FOLDER   = os.path.join(os.getcwd(), "sitemaps")
CHILD_FOLDER     = os.path.join(os.getcwd(), "child-sitemaps")
OTHER_CHILD_FOLDER = os.path.join(os.getcwd(), "other-child-sitemaps")
CURR_DIR         = os.path.dirname(os.getcwd())
SITEMAP_INDEX    = "https://wwww.booking.com/"
FOUND_URL_PATH = "found_url.json"

def clean_property_url(url: str) -> str:
    """
    Strip query params and fragment from URL.
    e.g. https://www.booking.com/hotel/id/grand-aulia-padang-panjang.html?aid=304142&...
    ->   https://www.booking.com/hotel/id/grand-aulia-padang-panjang.html
    """
    base = urlunparse(urlparse(url)._replace(query="", fragment=""))
    return base.rstrip("/")

def ask_customer_id() -> int:
    while True:
        raw = input("customer_id (integer): ").strip()
        try:
            return int(raw)
        except ValueError:
            print("  -> not an integer, try again.")

def update_found_url(customer_id: int, cleaned_url: str) -> bool:
    with open(FOUND_URL_PATH, "r", encoding="utf-8") as f:
        data = json.load(f)

    for entry in data:
        if entry.get("customer_id") == customer_id:
            old = entry.get("url", "")
            if old == cleaned_url:
                print(f"[=] customer_id {customer_id} already has this URL, nothing to do.")
                return False

            print(f"    name : {entry.get('properties_name')}")
            print(f"    old  : {old}")
            print(f"    new  : {cleaned_url}")
            if input("    write this change? [y/N]: ").strip().lower() != "y":
                print("[-] skipped.")
                return False

            entry["url"] = cleaned_url
            with open(FOUND_URL_PATH, "w", encoding="utf-8") as f:
                json.dump(data, f, indent=4, ensure_ascii=False)
            print("[+] saved.")
            return True

    print(f"[!] customer_id {customer_id} not found in found_url.json — nothing written.")
    return False


driver = build_driver(CURR_DIR, headless=IS_VPS)
wait = WebDriverWait(driver, PAGE_TIMEOUT)
driver.get("https://www.booking.com/")

try:
    while True:
        print("\n--- Search the property in the browser, then come back here. ---")
        input("Press Enter once the property page is open... ")

        # Switch to the most recently opened tab if multiple tabs exist
        handles = driver.window_handles
        if len(handles) > 1:
            driver.switch_to.window(handles[-1])

        current_url = driver.current_url
        cleaned = clean_property_url(current_url)
        print(f"[url] raw     : {current_url}")
        print(f"[url] cleaned : {cleaned}")

        customer_id = ask_customer_id()
        update_found_url(customer_id, cleaned)

        if input("\nAnother property? [y/N]: ").strip().lower() != "y":
            break
finally:
    driver.quit()
# Out:
# 17:52:40 [INFO] Auto-detected Chrome (registry): 151.0.7922.76 → major version 151
# 17:52:45 [INFO] patching driver executable C:\Users\anton\appdata\roaming\undetected_chromedriver\undetected_chromedriver.exe
# 17:52:46 [INFO] UC Chrome started in headed mode via Xvfb
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/hotel/id/villa-sekembang-ubud.id.html
# [url] cleaned : https://www.booking.com/hotel/id/villa-sekembang-ubud.id.html
#     name : Ubud Sekembang Sari
#     old  :
#     new  : https://www.booking.com/hotel/id/villa-sekembang-ubud.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/hotel/id/casa-doreena-villa-by-betterplace.id.html
# [url] cleaned : https://www.booking.com/hotel/id/casa-doreena-villa-by-betterplace.id.html
#     name : Manah Shanti Resort
#     old  : https://www.booking.com/hotel/id/manah-shanti-resort-ubud.id.html
#     new  : https://www.booking.com/hotel/id/casa-doreena-villa-by-betterplace.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/hotel/id/casa-doreena-villa-by-betterplace.id.html
# [url] cleaned : https://www.booking.com/hotel/id/casa-doreena-villa-by-betterplace.id.html
#     name : Villa Casa Doreena Canggu By Moria
#     old  :
#     new  : https://www.booking.com/hotel/id/casa-doreena-villa-by-betterplace.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/hotel/id/villa-damai-canggu-kabupaten-badung.id.html
# [url] cleaned : https://www.booking.com/hotel/id/villa-damai-canggu-kabupaten-badung.id.html
#     name : Villa Damai Canggu
#     old  :
#     new  : https://www.booking.com/hotel/id/villa-damai-canggu-kabupaten-badung.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/hotel/id/los-cabos-suite.en-gb.html
# [url] cleaned : https://www.booking.com/hotel/id/los-cabos-suite.en-gb.html
#     name : Villa De Belleza
#     old  :
#     new  : https://www.booking.com/hotel/id/los-cabos-suite.en-gb.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/hotel/id/deva-bali-villa.id.html
# [url] cleaned : https://www.booking.com/hotel/id/deva-bali-villa.id.html
#     name : Villa Deva Ubud
#     old  :
#     new  : https://www.booking.com/hotel/id/deva-bali-villa.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/hotel/id/villa-d-ruja-ubud.id.html
# [url] cleaned : https://www.booking.com/hotel/id/villa-d-ruja-ubud.id.html
#     name : Villa D'Ruja Ubud
#     old  :
#     new  : https://www.booking.com/hotel/id/villa-d-ruja-ubud.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/hotel/id/villa-felicia-canggu-by-moria.id.html
# [url] cleaned : https://www.booking.com/hotel/id/villa-felicia-canggu-by-moria.id.html
#     name : Villa Falicia Canggu by Maria
#     old  :
#     new  : https://www.booking.com/hotel/id/villa-felicia-canggu-by-moria.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/hotel/id/villa-gajah-mas-bedugul.id.html
# [url] cleaned : https://www.booking.com/hotel/id/villa-gajah-mas-bedugul.id.html
#     name : Villa Gajah Mas Bedugul
#     old  :
#     new  : https://www.booking.com/hotel/id/villa-gajah-mas-bedugul.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/hotel/id/villa-jempana.id.html
# [url] cleaned : https://www.booking.com/hotel/id/villa-jempana.id.html
#     name : Villa Jempana Kintamani
#     old  :
#     new  : https://www.booking.com/hotel/id/villa-jempana.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/hotel/id/dau-villa.id.html
# [url] cleaned : https://www.booking.com/hotel/id/dau-villa.id.html
#     name : Villa Kebun Jeruk Syariah
#     old  :
#     new  : https://www.booking.com/hotel/id/dau-villa.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/hotel/id/villa-kuma-ubud.id.html
# [url] cleaned : https://www.booking.com/hotel/id/villa-kuma-ubud.id.html
#     name : Villa Kuma By Moria
#     old  :
#     new  : https://www.booking.com/hotel/id/villa-kuma-ubud.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/hotel/id/seminyak-villa-lumina.id.html
# [url] cleaned : https://www.booking.com/hotel/id/seminyak-villa-lumina.id.html
#     name : Villa Lumina B
#     old  :
#     new  : https://www.booking.com/hotel/id/seminyak-villa-lumina.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/hotel/id/beach-villa-matanai.id.html
# [url] cleaned : https://www.booking.com/hotel/id/beach-villa-matanai.id.html
#     name : Villa Matanai Candidasa
#     old  :
#     new  : https://www.booking.com/hotel/id/beach-villa-matanai.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/hotel/id/villa-pantai-karang.id.html?aid=1893449&label=metagha-link-LUID-hotel-5003101_dev-desktop_los-1_bw-42_dow-Tuesday_defdate-1_room-0_gstadt-2_rateid-public_aud-0_gacid-21404703723_mcid-33_ppa-0_clrid-0_ad-1_gstkid-0_checkin-20260922_ppt-Tag_lp-2360_r-6378689445687443831&sid=0a563ca90918ac38ddca67612af8da2e&all_sr_blocks=500310102_0_2_0_0&checkin=2026-09-22&checkout=2026-09-23&dest_id=5003101&dest_type=hotel&dist=0&group_adults=2&group_children=0&hapos=1&highlighted_blocks=500310102_0_2_0_0&hpos=1&matching_block_id=500310102_0_2_0_0&no_rooms=1&req_adults=2&req_children=0&room1=A%2CA&sb_price_type=total&sr_order=popularity&sr_pri_blocks=500310102_0_2_0_0__254160509&srepoch=1786442443&srpvid=21414664276600f8&type=total&ucfs=1&
# [url] cleaned : https://www.booking.com/hotel/id/villa-pantai-karang.id.html
#     name : Villa Pantai Karang Sanur
#     old  :
#     new  : https://www.booking.com/hotel/id/villa-pantai-karang.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/hotel/id/villa-sama-canggu.id.html?aid=356980&label=gog235jc-10CAsoaEIRdmlsbGEtc2FtYS1jYW5nZ3VIElgDaGiIAQGYATO4ARfIAQzYAQPoAQH4AQGIAgGoAgG4Atvl69MGwAIB0gIkYzc1NmY4YzQtODdhMS00MTU5LWFkYmUtNGFlNzlkYjVmMTdj2AIB4AIB&sid=0a563ca90918ac38ddca67612af8da2e&checkin=2026-09-22&checkout=2026-09-23&dest_id=900048236&dest_type=city&dist=0&group_adults=2&group_children=0&hapos=1&hpos=1&no_rooms=1&req_adults=2&req_children=0&room1=A%2CA&sb_price_type=total&soh=1&sr_order=popularity&srepoch=1786442462&srpvid=62bb466ed04500bc&type=total&ucfs=1&#no_availability_msg
# [url] cleaned : https://www.booking.com/hotel/id/villa-sama-canggu.id.html
#     name : Villa Sama
#     old  :
#     new  : https://www.booking.com/hotel/id/villa-sama-canggu.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/hotel/id/villa-sampurna-kabupaten-gianyar.id.html?aid=356980&label=gog235jc-10CAsoaEIgdmlsbGEtc2FtcHVybmEta2FidXBhdGVuLWdpYW55YXJIElgDaGiIAQGYATO4ARfIAQzYAQPoAQH4AQGIAgGoAgG4AvTl69MGwAIB0gIkNjg0NzVlOWQtODI0Zi00ODkxLWJiYjgtMGE3NTZhNmUxM2My2AIB4AIB&sid=0a563ca90918ac38ddca67612af8da2e&all_sr_blocks=1378533401_409991819_4_0_0&checkin=2026-09-22&checkout=2026-09-23&dest_id=-2701757&dest_type=city&dist=0&group_adults=2&group_children=0&hapos=1&highlighted_blocks=1378533401_409991819_4_0_0&hpos=1&matching_block_id=1378533401_409991819_4_0_0&no_rooms=1&req_adults=2&req_children=0&room1=A%2CA&sb_price_type=total&sr_order=popularity&sr_pri_blocks=1378533401_409991819_4_0_0__197600000&srepoch=1786442490&srpvid=8768467b85fa0133&type=total&ucfs=1&
# [url] cleaned : https://www.booking.com/hotel/id/villa-sampurna-kabupaten-gianyar.id.html
#     name : Villa Sampurna by morian
#     old  :
#     new  : https://www.booking.com/hotel/id/villa-sampurna-kabupaten-gianyar.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/hotel/id/sundari-villa-by-kozystay-canggu.id.html?aid=356980&label=gog235jc-10CAsoaEIgc3VuZGFyaS12aWxsYS1ieS1rb3p5c3RheS1jYW5nZ3VIElgDaGiIAQGYATO4ARfIAQzYAQPoAQH4AQGIAgGoAgG4Apjm69MGwAIB0gIkMmU4MmJiNGUtZDdmMi00ZmYwLWI2NTQtY2Q3Mzk4M2ZjNjlj2AIB4AIB&sid=0a563ca90918ac38ddca67612af8da2e&all_sr_blocks=1466266901_417947981_0_0_0_1158717&checkin=2026-09-22&checkout=2026-09-23&dest_id=900048236&dest_type=city&dist=0&group_adults=2&group_children=0&hapos=1&highlighted_blocks=1466266901_417947981_0_0_0_1158717&hpos=1&matching_block_id=1466266901_417947981_0_0_0_1158717&no_rooms=1&req_adults=2&req_children=0&room1=A%2CA&sb_price_type=total&sr_order=popularity&sr_pri_blocks=1466266901_417947981_0_0_0_1158717_296769600&srepoch=1786442522&srpvid=661c468ce0220217&type=total&ucfs=1&
# [url] cleaned : https://www.booking.com/hotel/id/sundari-villa-by-kozystay-canggu.id.html
#     name : Villa Sundaria
#     old  :
#     new  : https://www.booking.com/hotel/id/sundari-villa-by-kozystay-canggu.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/searchresults.id.html?aid=356980&label=gog235jc-10CAsoaEIidmlsbGEtd2FudGlsYW4tcHV0aWgta290YS1kZW5wYXNhckgSWANoaIgBAZgBM7gBF8gBDNgBA-gBAfgBAYgCAagCAbgC4-br0wbAAgHSAiRhNTBmZWE5MC0zOTJhLTQwZDUtYmNiOS1kMTExZWE4ZjU3OWbYAgHgAgE&redirected=1&city=325646&highlighted_hotels=5369714&hlrd=user_sh&source=hotel&checkin=2026-09-22&checkout=2026-09-23&keep_landing=1&sid=0a563ca90918ac38ddca67612af8da2e
# [url] cleaned : https://www.booking.com/searchresults.id.html
#   -> not an integer, try again.
#     name : 3
#     old  :
#     new  : https://www.booking.com/searchresults.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/searchresults.id.html?aid=356980&label=gog235jc-10CAsoaEIidmlsbGEtd2FudGlsYW4tcHV0aWgta290YS1kZW5wYXNhckgSWANoaIgBAZgBM7gBF8gBDNgBA-gBAfgBAYgCAagCAbgC4-br0wbAAgHSAiRhNTBmZWE5MC0zOTJhLTQwZDUtYmNiOS1kMTExZWE4ZjU3OWbYAgHgAgE&redirected=1&city=325646&highlighted_hotels=5369714&hlrd=user_sh&source=hotel&checkin=2026-09-22&checkout=2026-09-23&keep_landing=1&sid=0a563ca90918ac38ddca67612af8da2e
# [url] cleaned : https://www.booking.com/searchresults.id.html
#     name : Villa Wantilan Putih Sanur
#     old  :
#     new  : https://www.booking.com/searchresults.id.html
# [-] skipped.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/searchresults.id.html?aid=356980&label=gog235jc-10CAsoaEIidmlsbGEtd2FudGlsYW4tcHV0aWgta290YS1kZW5wYXNhckgSWANoaIgBAZgBM7gBF8gBDNgBA-gBAfgBAYgCAagCAbgC4-br0wbAAgHSAiRhNTBmZWE5MC0zOTJhLTQwZDUtYmNiOS1kMTExZWE4ZjU3OWbYAgHgAgE&redirected=1&city=325646&highlighted_hotels=5369714&hlrd=user_sh&source=hotel&checkin=2026-09-22&checkout=2026-09-23&keep_landing=1&sid=0a563ca90918ac38ddca67612af8da2e
# [url] cleaned : https://www.booking.com/searchresults.id.html
#     name : Villa Wantilan Putih Sanur
#     old  :
#     new  : https://www.booking.com/searchresults.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/searchresults.id.html?aid=356980&label=gog235jc-10CAsoaEIPd2F0dS12aWxsYS11YnVkSBJYA2hoiAEBmAEzuAEXyAEM2AED6AEB-AEBiAIBqAIBuAKP5-vTBsACAdICJGNmOGY2ZmExLTc1MzYtNDNiMy1iMTYwLWE1NmVlYTI4MDc1ONgCAeACAQ&redirected=1&city=-2701757&highlighted_hotels=14711420&hlrd=user_sh&source=hotel&checkin=2026-09-22&checkout=2026-09-23&keep_landing=1&sid=0a563ca90918ac38ddca67612af8da2e
# [url] cleaned : https://www.booking.com/searchresults.id.html
#     name : Villa Wa tu Ubud
#     old  :
#     new  : https://www.booking.com/searchresults.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/hotel/id/villa-wantilan-putih-kota-denpasar.id.html?aid=356980&label=gog235jc-10CAsoaEIidmlsbGEtd2FudGlsYW4tcHV0aWgta290YS1kZW5wYXNhckgSWANoaIgBAZgBM7gBF8gBDNgBA-gBAfgBAYgCAagCAbgCrOfr0wbAAgHSAiRjYTA2Y2M1ZC05ZmNiLTQyNDYtOGIwMC0wMDY5ZmQzMjFmYTjYAgHgAgE&sid=0a563ca90918ac38ddca67612af8da2e&all_sr_blocks=536971402_190746513_0_2_0_470871&checkin=2026-09-22&checkout=2026-09-23&dest_id=325646&dest_type=city&dist=0&group_adults=2&group_children=0&hapos=1&highlighted_blocks=536971402_190746513_0_2_0_470871&hpos=1&matching_block_id=536971402_190746513_0_2_0_470871&no_rooms=1&req_adults=2&req_children=0&room1=A%2CA&sb_price_type=total&sr_order=popularity&sr_pri_blocks=536971402_190746513_0_2_0_470871_271270200&srepoch=1786442671&srpvid=8fa546d628a30041&type=total&ucfs=1&
# [url] cleaned : https://www.booking.com/hotel/id/villa-wantilan-putih-kota-denpasar.id.html
#     name : Villa Wantilan Putih Sanur
#     old  : https://www.booking.com/searchresults.id.html
#     new  : https://www.booking.com/hotel/id/villa-wantilan-putih-kota-denpasar.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/hotel/id/watu-villa-ubud.id.html?aid=356980&label=gog235jc-10CAsoaEIPd2F0dS12aWxsYS11YnVkSBJYA2hoiAEBmAEzuAEXyAEM2AED6AEB-AEBiAIBqAIBuALB5-vTBsACAdICJDYwNDBhNzZlLWNmNzUtNGY4Yi1iZDEyLTQ3NmM5YzI5YTdlM9gCAeACAQ&sid=0a563ca90918ac38ddca67612af8da2e&all_sr_blocks=1471142002_428784619_0_0_0&checkin=2026-09-22&checkout=2026-09-23&dest_id=-2701757&dest_type=city&dist=0&group_adults=2&group_children=0&hapos=1&highlighted_blocks=1471142002_428784619_0_0_0&hpos=1&matching_block_id=1471142002_428784619_0_0_0&no_rooms=1&req_adults=2&req_children=0&room1=A%2CA&sb_price_type=total&sr_order=popularity&sr_pri_blocks=1471142002_428784619_0_0_0__107229800&srepoch=1786442695&srpvid=d2b946e1b28f0148&type=total&ucfs=1&
# [url] cleaned : https://www.booking.com/hotel/id/watu-villa-ubud.id.html
#     name : Villa Wa tu Ubud
#     old  : https://www.booking.com/searchresults.id.html
#     new  : https://www.booking.com/hotel/id/watu-villa-ubud.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/hotel/id/wanaseta-guesthouse.id.html?aid=356980&label=gog235jc-10CAsoaEITd2FuYXNldGEtZ3Vlc3Rob3VzZUgSWANoaIgBAZgBM7gBF8gBDNgBA-gBAfgBAYgCAagCAbgC_-fr0wbAAgHSAiRkOWVkYWQ2My1kYzliLTRkMGUtOWUxNC1lNDY5NDUzYjAyNzfYAgHgAgE&sid=0a563ca90918ac38ddca67612af8da2e&all_sr_blocks=1346999601_407059247_0_1_0&checkin=2026-09-22&checkout=2026-09-23&dest_id=325689&dest_type=city&dist=0&group_adults=2&group_children=0&hapos=1&highlighted_blocks=1346999601_407059247_0_1_0&hpos=1&matching_block_id=1346999601_407059247_0_1_0&no_rooms=1&req_adults=2&req_children=0&room1=A%2CA&sb_price_type=total&sr_order=popularity&sr_pri_blocks=1346999601_407059247_0_1_0__64000000&srepoch=1786442754&srpvid=72b447009bbb0146&type=total&ucfs=1&
# [url] cleaned : https://www.booking.com/hotel/id/wanaseta-guesthouse.id.html
#     name : Wanaseta Guest House
#     old  :
#     new  : https://www.booking.com/hotel/id/wanaseta-guesthouse.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# [url] raw     : https://www.booking.com/hotel/id/wisma-anugerah-homestay.id.html?aid=356980&label=gog235jc-10CAsoaEIXd2lzbWEtYW51Z2VyYWgtaG9tZXN0YXlIElgDaGiIAQGYATO4ARfIAQzYAQPoAQH4AQGIAgGoAgG4Ap7o69MGwAIB0gIkMDQzODk1NjAtMjA3Yi00YjUxLTk2MTctZmM4MGE2OWIxMjk22AIB4AIB&sid=0a563ca90918ac38ddca67612af8da2e&all_sr_blocks=995049903_429343842_0_0_0_838541&checkin=2026-09-22&checkout=2026-09-23&dest_id=-2673975&dest_type=city&dist=0&group_adults=2&group_children=0&hapos=1&highlighted_blocks=995049903_429343842_0_0_0_838541&hpos=1&matching_block_id=995049903_429343842_0_0_0_838541&no_rooms=1&req_adults=2&req_children=0&room1=A%2CA&sb_price_type=total&sr_order=popularity&sr_pri_blocks=995049903_429343842_0_0_0_838541_19760000&srepoch=1786442794&srpvid=5a6c471031d700dd&type=total&ucfs=1&
# [url] cleaned : https://www.booking.com/hotel/id/wisma-anugerah-homestay.id.html
#     name : Wisma Anugrah
#     old  :
#     new  : https://www.booking.com/hotel/id/wisma-anugerah-homestay.id.html
# [+] saved.
#
# --- Search the property in the browser, then come back here. ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 60
#      58 while True:
#      59     print("\n--- Search the property in the browser, then come back here. ---")
# ---> 60     input("Press Enter once the property page is open... ")
#      62     # Switch to the most recently opened tab if multiple tabs exist
#      63     handles = driver.window_handles
#
# File c:\Programming\.vscode\.venv\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File c:\Programming\.vscode\.venv\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import pandas as pd
import pickle as pkl

read_df = pd.read_pickle("scraping_customer_eb.pkl")
read_df
# Out:
#       property_name             room_type   ota_source  price_details  \
# 0               257    Vila 1 Kamar Tidur  Booking.com              0
# 1               257    Vila 1 Kamar Tidur  Booking.com              0
# 2               257    Vila 1 Kamar Tidur  Booking.com              0
# 3               257    Vila 1 Kamar Tidur  Booking.com              0
# 4                59    Vila 1 Kamar Tidur  Booking.com              0
# ...             ...                   ...          ...            ...
# 1960            307  Standard Single Room  Booking.com         193500
# 1961            307           Double Room  Booking.com         223913
# 1962            307  Superior Double Room  Booking.com         231000
# 1963            307   Economy Single Room  Booking.com         139900
# 1964            307  Standard Single Room  Booking.com         193500
#
#                                           notes_details date_scrapped  \
# 0                                           Pilih kamar    2026-08-24
# 1                                           Pilih kamar    2026-08-24
# 2                                           Pilih kamar    2026-08-24
# 3                                           Pilih kamar    2026-08-24
# 4                                           Pilih kamar    2026-08-24
# ...                                                 ...           ...
# 1960  Free cancellation before August 28, 2026 • Pay...    2026-08-21
# 1961  Free cancellation before September 13, 2026 • ...    2026-08-21
# 1962  Free cancellation before September 13, 2026 • ...    2026-08-21
# 1963  Free cancellation before September 13, 2026 • ...    2026-08-21
# 1964  Free cancellation before September 13, 2026 • ...    2026-08-21
#
#      target_date    category villa_or_hotel rating
# 0     2026-09-07  early-book           None   None
# 1     2026-09-07  early-book           None   None
# 2     2026-09-23  early-book           None   None
# 3     2026-09-23  early-book           None   None
# 4     2026-09-09  early-book           None   None
# ...          ...         ...            ...    ...
# 1960  2026-09-04  early-book           None   None
# 1961  2026-09-20  early-book           None   None
# 1962  2026-09-20  early-book           None   None
# 1963  2026-09-20  early-book           None   None
# 1964  2026-09-20  early-book           None   None
#
# [1965 rows x 10 columns]
