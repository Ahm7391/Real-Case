# %%
import pandas as pd

peek_df = pd.read_pickle('scraping_database_lm_customer.pkl')
peek_df
# Out:
#                       property_name           room_type   ota_source  \
# 0  Hotel Pratisarawirya by The Loka  Deluxe Double Room  Booking.com
#
#    price_details notes_details date_scrapped target_date     category  \
# 0         599747  Select Rooms    2026-09-22  2026-09-29  last-minute
#
#   villa_or_hotel rating
# 0           None   None
